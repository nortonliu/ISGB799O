# %%
import pandas as pd 
from textblob import TextBlob
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\norton\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
column_names = ['date', 'username','tweet']
#create a dataframe, set column names, separate data with /t, no header
df = pd.read_csv('C:/Users/norton/Google 云端硬盘（qliu101@fordham.edu）/1. Fall 2019/2. Web Analytics/Project/FINAL/finalmaster.csv',
                  delimiter=',', 
                  encoding='ansi',
                  header=0, 
                  names=column_names)

# %%
df
# Out:
#            date         username  \
# 0     2019/8/31      turntmosfet
# 1     2019/8/31          max_dtx
# 2     2019/8/31     kristinapuga
# 3     2019/8/31     mydiabolical
# 4     2019/8/31       drlipartia
# 5     2019/8/31      shar_parker
# 6     2019/8/31  clemsonhandyman
# 7     2019/8/31     glorianne329
# 8     2019/8/31  drachonathewolf
# 9     2019/8/31        sssaaadie
# 10    2019/8/31      bigpapavito
# 11    2019/8/31          max_dtx
# 12    2019/8/31         ialiazam
# 13    2019/8/31         ialiazam
# 14    2019/8/31              NaN
# 15    2019/8/31  lolavillanuevae
# 16    2019/8/31        imadadcom
# 17    2019/8/31           tinovr
# 18    2019/8/31      azcancerguy
# 19    2019/8/31      barrclifton
# 20    2019/8/31    massoudkhwaja
# 21    2019/8/31      jengirl0901
# 22    2019/8/31          nyactor
# 23    2019/8/31          lmmwill
# 24    2019/8/31       barryhcain
# 25    2019/8/31      funcitywest
# 26    2019/8/31      forceofgaia
# 27    2019/8/31    benjonesrocks
# 28    2019/8/31         loeynorq
# 29    2019/8/31        nbptrocks
# ...         ...              ...
# 4356   2019/5/6     tedteddymann
# 4357   2019/5/6     loriminor247
# 4358   2019/5/6        lilwoodys
# 4359   2019/5/6        _nslnlhcr
# 4360   2019/5/6     garyrsimonds
# 4361   2019/5/6   lazrsquadbig10
# 4362   2019/5/6       middletim2
# 4363   2019/5/6       heymayahey
# 4364   2019/5/6      shepardsolo
# 4365   2019/5/6      spideysuggs
# 4366   2019/5/6  flow_likea_wave
# 4367   2019/5/6          sadolan
# 4368   2019/5/6      satchelsbbq
# 4369   2019/5/6  impossiblefoods
# 4370   2019/5/6  impossiblefoods
# 4371   2019/5/6     tedteddymann
# 4372   2019/5/6     loriminor247
# 4373   2019/5/6        lilwoodys
# 4374   2019/5/6        _nslnlhcr
# 4375   2019/5/6     garyrsimonds
# 4376   2019/5/6   lazrsquadbig10
# 4377   2019/5/6       middletim2
# 4378   2019/5/6       heymayahey
# 4379   2019/5/6      shepardsolo
# 4380   2019/5/6      spideysuggs
# 4381   2019/5/6  flow_likea_wave
# 4382   2019/5/6      justindubin
# 4383   2019/5/6       jesuisj0sh
# 4384   2019/5/6        mhsmiriam
# 4385   2019/5/6      tiffanireal
#
#                                                   tweet
# 0     Hot take: Beyond/impossible burgers are not as...
# 1     Went to try the @ImpossibleFoods Whopper from ...
# 2     Did anyone else get a stomach ache for days af...
# 3                Have you tried the #impossibleburger ?
# 4     Beef 馃崝. And when I want bean quinoa and onion...
# 5                   @ImpossibleFoods #impossiblewhopper
# 6     #impossiblewhopper had 2nd one an it鈥檚 good ag...
# 7     Ok @BurgerKing 馃憦 馃憦 馃憦 my vegetarian husband ...
# 8     Hey @BurgerKing , I'm not stupid. The #impossi...
# 9                                    #impossiblewhopper
# 10    @McDonalds I've had the #ImpossibleWhopper, an...
# 11    Went to try the @ImpossibleFoods Whopper from ...
# 12    I am a muslim and its almost impossible to eat...
# 13    Thank you @BurgerKing for introducing @Impossi...
# 14    I just watched #WhatInTheHealth ... soon as it...
# 15    @BurgerKing where can I get the #impossiblewho...
# 16    Do you still serve the older vegetarian hambur...
# 17    does the claim that the @BurgerKing #impossibl...
# 18    Tried that new #ImpossibleWhopper this morning...
# 19    Impossible Burger for Burger King.  It鈥檚 REALL...
# 20    #BeyondMeat, #impossiblewhopper, #AntiAnimalAs...
# 21    @BurgerKing love 馃挄 your #impossiblewhopper bu...
# 22    DOES EVERYONE carry the #impossible burger now...
# 23    My youngest is home from school for the long w...
# 24    I give the #impossiblewhopper from @BurgerKing...
# 25    Horses are being eliminated to make room for c...
# 26    My family loves this burger! It鈥檚 the kind bur...
# 27    @BurgerKing I love the #impossiblewhopper but ...
# 28                                   #impossiblewhopper
# 29                                   #impossiblewhopper
# ...                                                 ...
# 4356  Looks like he's rocking a charcoal beard in th...
# 4357  New phrase: 鈥渟o-and-so is an impossible burger...
# 4358  You can substitute any of our burgers with the...
# 4359  I convinced everyone in my office to try the i...
# 4360  tried the impossible burger. it's close. close...
# 4361  If you're looking for an edge on argument, pla...
# 4362  If you are discussing the despair of climate c...
# 4363  Insulin production. HFCS production. For the #...
# 4364  WE NEED #impossibleburger or #BeyondMeat PLEAS...
# 4365  @Wendys any plans to bring a #veganburger to t...
# 4366  managed to get my hands on an #impossibleburge...
# 4367  I鈥檓 sure @prettygotugly will report back to me...
# 4368  I just ate an Impossible Burger and like it!! ...
# 4369  It's like 馃幍 to our ears to hear that you're a...
# 4370  It鈥檚 too early to say when, but we look forwar...
# 4371  Looks like he's rocking a charcoal beard in th...
# 4372  New phrase: 鈥渟o-and-so is an impossible burger...
# 4373  You can substitute any of our burgers with the...
# 4374  I convinced everyone in my office to try the i...
# 4375  tried the impossible burger. it's close. close...
# 4376  If you're looking for an edge on argument, pla...
# 4377  If you are discussing the despair of climate c...
# 4378  Insulin production. HFCS production. For the #...
# 4379  WE NEED #impossibleburger or #BeyondMeat PLEAS...
# 4380  @Wendys any plans to bring a #veganburger to t...
# 4381  managed to get my hands on an #impossibleburge...
# 4382  Just tried the Beyond Burger and I was SHOCKED...
# 4383  Dear @BURGERFI I don鈥檛 know why y鈥檃ll can鈥檛 ge...
# 4384  Thank you, and thanks for carrying the #Beyond...
# 4385         I can't wait to try the #impossiblewhopper
#
# [4386 rows x 3 columns]

# %%
df['tweet'] = df['tweet'].fillna('999')
missing = df[(df.tweet == '999')].index.tolist()
df = df.drop(missing)
print(df['tweet'].isnull().value_counts())

attitudes1 = list()
attitudes2 = list()

for tweet in df['tweet']:
    testimonial = TextBlob(str(tweet))
    attitude1 = testimonial.sentiment.polarity
    attitudes1.append(attitude1)
df['textblob'] = attitudes1

sid = SentimentIntensityAnalyzer()
for tweet in df['tweet']:
    attitude2 = sid.polarity_scores(tweet)['compound']
    attitudes2.append(attitude2)
df['nltk_vader'] = attitudes2

print(df.head())
print(df.tail())

df.to_csv('attitudes_all.csv',mode='w')
# Out:
# False    4386
# Name: tweet, dtype: int64
#         date      username                                              tweet  \
# 0  2019/8/31   turntmosfet  Hot take: Beyond/impossible burgers are not as...
# 1  2019/8/31       max_dtx  Went to try the @ImpossibleFoods Whopper from ...
# 2  2019/8/31  kristinapuga  Did anyone else get a stomach ache for days af...
# 3  2019/8/31  mydiabolical             Have you tried the #impossibleburger ?
# 4  2019/8/31    drlipartia  Beef 馃崝. And when I want bean quinoa and onion...
#
#    textblob  nltk_vader
# 0  0.261111     -0.3412
# 1  0.000000     -0.4767
# 2  0.000000     -0.3818
# 3  0.000000      0.0000
# 4  0.000000     -0.2263
#           date         username  \
# 4381  2019/5/6  flow_likea_wave
# 4382  2019/5/6      justindubin
# 4383  2019/5/6       jesuisj0sh
# 4384  2019/5/6        mhsmiriam
# 4385  2019/5/6      tiffanireal
#
#                                                   tweet  textblob  nltk_vader
# 4381  managed to get my hands on an #impossibleburge...  0.468750      0.4534
# 4382  Just tried the Beyond Burger and I was SHOCKED...  0.071429      0.8243
# 4383  Dear @BURGERFI I don鈥檛 know why y鈥檃ll can鈥檛 ge... -0.095833     -0.5390
# 4384  Thank you, and thanks for carrying the #Beyond...  0.616667      0.9199
# 4385         I can't wait to try the #impossiblewhopper  0.000000      0.0000

# %%
df2=pd.read_csv('C:/Users/norton/Google 云端硬盘（qliu101@fordham.edu）/1. Fall 2019/2. Web Analytics/Project/FINAL/attitudes_all.csv',
               delimiter=',',
               encoding='utf-8',
               header=0,
               names=['date', 'username','tweet','textblob','nltk_vader'])

# %%
df2.describe()
# Out:
#           textblob   nltk_vader
# count  4386.000000  4386.000000
# mean      0.131143     0.242736
# std       0.333373     0.461701
# min      -1.000000    -0.953100
# 25%       0.000000     0.000000
# 50%       0.076389     0.249950
# 75%       0.329661     0.636900
# max       1.000000     0.985800
