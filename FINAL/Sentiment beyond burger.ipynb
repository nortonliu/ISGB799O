# %%
import pandas as pd 
from textblob import TextBlob
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\norton\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
column_names = ['date', 'username','tweet']
#create a dataframe, set column names, separate data with /t, no header
df = pd.read_csv('C:/Users/norton/Google 云端硬盘（qliu101@fordham.edu）/1. Fall 2019/2. Web Analytics/Project/FINAL/finalbeyondburger.csv',
                  delimiter=',', 
                  encoding='ansi',
                  header=0, 
                  names=column_names)

# %%
df
# Out:
#             date         username  \
# 0      2019/8/31       drlipartia
# 1      2019/8/30      avoriginals
# 2      2019/8/29          nenagh9
# 3      2019/8/27      leestilesrh
# 4      2019/8/26       modtechent
# 5      2019/8/26     lavishlyhers
# 6      2019/8/26   carolynewilson
# 7      2019/8/26        menumavin
# 8      2019/8/24        mysharona
# 9      2019/8/24      rob_egerton
# 10     2019/8/23    the_b_company
# 11     2019/8/23    the_b_company
# 12     2019/8/23        watchmala
# 13     2019/8/23      borders_iii
# 14     2019/8/23         malacoid
# 15     2019/8/23       theonemule
# 16     2019/8/23      jillpainter
# 17     2019/8/22   profastrosarah
# 18     2019/8/22    crushitcarlos
# 19     2019/8/22   veganspiceblog
# 20     2019/8/22         blakwyze
# 21     2019/8/22     monikaelling
# 22     2019/8/21     learnedlemur
# 23     2019/8/21     gamewithjohn
# 24     2019/8/20     paulashatsky
# 25     2019/8/20     paulashatsky
# 26     2019/8/19     sharicklamay
# 27     2019/8/19         burgerfi
# 28     2019/8/19    sundayhhtimes
# 29     2019/8/18      thequeenrbc
# ...          ...              ...
# 1617   2016/5/23      quinnemmett
# 1618   2016/5/23          combfit
# 1619   2014/3/23  thequeen88folse
# 1620   2014/2/20   shipwandsworth
# 1621    2013/7/6     triplestudly
# 1622   2013/5/20       saadhlatif
# 1623   2013/5/20      ayeshamulla
# 1624    2013/4/6    imjust_imanii
# 1625  2012/11/24  thespiderman630
# 1626  2012/11/24  thespiderman630
# 1627  2012/10/19  thespiderman630
# 1628  2012/10/19  thespiderman630
# 1629  2012/10/12  gamersblocrival
# 1630   2012/8/19   amberr_nichole
# 1631   2012/6/11     drumz_of_war
# 1632    2012/5/9       sec102rowd
# 1633   2012/3/24     _getlikemee_
# 1634   2012/3/24     _getlikemee_
# 1635    2012/3/6         rachal79
# 1636   2012/2/20         graylo86
# 1637    2012/2/4          robb281
# 1638    2012/2/3        haythadon
# 1639   2012/1/28    riverrwithana
# 1640   2011/12/9       justjelley
# 1641   2011/12/9   acissejdrazzah
# 1642   2011/12/9  mr_lightsplease
# 1643   2011/12/9      mr_98_rider
# 1644   2011/12/3     potato_wedge
# 1645  2011/11/30     potato_wedge
# 1646  2011/11/28       dangkennyy
#
#                                                   tweet
# 0     Beef 馃崝. And when I want bean quinoa and onion...
# 1     I had the #BEYONDBURGER last night for dinner ...
# 1641  Giving #beyondburger a try. It's packed, and w...
# 1642  "@deanthony_dee: My nigga I want some #BeyondB...
# 1643  My nigga I want some #BeyondBurger the new spo...
# 1644                      At #BeyondBurger ...again -_-
# 1645                                At #BeyondBurger (:
# 1646  Going to try out this new place that just open...
#
# [1647 rows x 3 columns]

# %%
df['tweet'] = df['tweet'].fillna('999')
missing = df[(df.tweet == '999')].index.tolist()
df = df.drop(missing)
print(df['tweet'].isnull().value_counts())

attitudes1 = list()
attitudes2 = list()

for tweet in df['tweet']:
    testimonial = TextBlob(str(tweet))
    attitude1 = testimonial.sentiment.polarity
    attitudes1.append(attitude1)
df['textblob'] = attitudes1

sid = SentimentIntensityAnalyzer()
for tweet in df['tweet']:
    attitude2 = sid.polarity_scores(tweet)['compound']
    attitudes2.append(attitude2)
df['nltk_vader'] = attitudes2

print(df.head())
print(df.tail())

df.to_csv('attitudes_beyond_burger.csv',mode='w')
# Out:
# False    1647
# Name: tweet, dtype: int64
#         date     username                                              tweet  \
# 0  2019/8/31   drlipartia  Beef 馃崝. And when I want bean quinoa and onion...
# 1  2019/8/30  avoriginals  I had the #BEYONDBURGER last night for dinner ...
# 2  2019/8/29      nenagh9                        Oh it鈥檚 the #BeyondBurger馃憤
# 3  2019/8/27  leestilesrh  #beyondburger was ok I guess. Best veggie burg...
# 4  2019/8/26   modtechent  Attention Everyone! The #impossiblewhopper by ...
#
#    textblob  nltk_vader
# 0  0.000000     -0.2263
# 1  0.304167      0.9371
# 2  0.000000      0.0000
# 3  0.750000      0.7506
# 4 -0.033333      0.8174
#             date         username  \
# 1642   2011/12/9  mr_lightsplease
# 1643   2011/12/9      mr_98_rider
# 1644   2011/12/3     potato_wedge
# 1645  2011/11/30     potato_wedge
# 1646  2011/11/28       dangkennyy
#
#                                                   tweet  textblob  nltk_vader
# 1642  "@deanthony_dee: My nigga I want some #BeyondB...  0.459091      0.4939
# 1643  My nigga I want some #BeyondBurger the new spo...  0.468182      0.4767
# 1644                      At #BeyondBurger ...again -_-  0.000000      0.0000
# 1645                                At #BeyondBurger (:  0.000000      0.4939
# 1646  Going to try out this new place that just open...  0.136364      0.0000

# %%
df2=pd.read_csv('C:/Users/norton/Google 云端硬盘（qliu101@fordham.edu）/1. Fall 2019/2. Web Analytics/Project/FINAL/attitudes_beyond_burger.csv',
               delimiter=',',
               encoding='utf-8',
               header=0,
               names=['date', 'username','tweet','textblob','nltk_vader'])

# %%
df2.describe()
# Out:
#           textblob   nltk_vader
# count  1647.000000  1647.000000
# mean      0.197311     0.274833
# std       0.331295     0.447294
# min      -1.000000    -0.948500
# 25%       0.000000     0.000000
# 50%       0.125000     0.338200
# 75%       0.416667     0.663950
# max       1.000000     0.970500
