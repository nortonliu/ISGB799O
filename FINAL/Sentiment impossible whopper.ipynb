# %%
import pandas as pd 
from textblob import TextBlob
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\norton\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
column_names = ['date', 'username','tweet']
#create a dataframe, set column names, separate data with /t, no header
df = pd.read_csv('C:/Users/norton/Google 云端硬盘（qliu101@fordham.edu）/1. Fall 2019/2. Web Analytics/Project/FINAL/finalimpossiblewhopper.csv', 
                  encoding='ansi',
                  header=0, 
                  names=column_names)

# %%
df
# Out:
#            date         username  \
# 0     2019/8/31      shar_parker
# 1     2019/8/31  clemsonhandyman
# 2     2019/8/31     glorianne329
# 3     2019/8/31  drachonathewolf
# 4     2019/8/31        sssaaadie
# 5     2019/8/31      bigpapavito
# 6     2019/8/31          max_dtx
# 7     2019/8/31         ialiazam
# 8     2019/8/31         ialiazam
# 9     2019/8/31              NaN
# 10    2019/8/31  lolavillanuevae
# 11    2019/8/31        imadadcom
# 12    2019/8/31           tinovr
# 13    2019/8/31      azcancerguy
# 14    2019/8/31      barrclifton
# 15    2019/8/31    massoudkhwaja
# 16    2019/8/31      jengirl0901
# 17    2019/8/31          nyactor
# 18    2019/8/31          lmmwill
# 19    2019/8/31       barryhcain
# 20    2019/8/31      funcitywest
# 21    2019/8/31      forceofgaia
# 22    2019/8/31    benjonesrocks
# 23    2019/8/31         loeynorq
# 24    2019/8/31        nbptrocks
# 25    2019/8/31    theshannankay
# 26    2019/8/31     krisnewmankr
# 27    2019/8/31      allenfarley
# 28    2019/8/31       asbilljosh
# 29    2019/8/31  rae_fromthe_bay
# ...         ...              ...
# 1915  2019/5/16      brianmasano
# 1916  2019/5/16      brianmasano
# 1917  2019/5/16      idiaz4muzik
# 1918  2019/5/16        lucyvazzz
# 1919  2019/5/15   kevinhrhubbard
# 1920  2019/5/15         miblaine
# 1921  2019/5/15        btwimyari
# 1922  2019/5/15      marilyn3770
# 1923  2019/5/15      brianmasano
# 1924  2019/5/15     violet_wangu
# 1925  2019/5/15       jonvmurphy
# 1926  2019/5/14     tylerbalaban
# 1927  2019/5/14       fizzieizzy
# 1928  2019/5/14   viatecnologica
# 1929  2019/5/14     cigarsnobmag
# 1930  2019/5/14  nicolasajimenez
# 1931  2019/5/14      rodhockaday
# 1932  2019/5/14      thejaygrove
# 1933  2019/5/14        ttanishal
# 1934  2019/5/14        ttanishal
# 1935  2019/5/14   aarongrubbworm
# 1936  2019/5/13    championlover
# 1937  2019/5/13     dantermaddox
# 1938  2019/5/12   angiemolly7616
# 1939  2019/5/11    nosaintsfan08
# 1940  2019/5/10     rachelkonrad
# 1941  2019/5/10     justinthaler
# 1942   2019/5/9       nickkeesey
# 1943   2019/5/8     rachelkonrad
# 1944   2019/5/6      tiffanireal
#
#                                                   tweet
# 0                   @ImpossibleFoods #impossiblewhopper
# 1     #impossiblewhopper had 2nd one an it鈥檚 good ag...
# 1940  Truth: @BurgerKing sells the #impossiblewhoppe...
# 1941  As long as that joke involves the #impossiblew...
# 1942  @BurgerKing when will the @ImpossibleFoods who...
# 1943  Fact: #impossibleWhopper is in 59 stores. That...
# 1944         I can't wait to try the #impossiblewhopper
#
# [1945 rows x 3 columns]

# %%
df['tweet'] = df['tweet'].fillna('999')
missing = df[(df.tweet == '999')].index.tolist()
df = df.drop(missing)
print(df['tweet'].isnull().value_counts())

attitudes1 = list()
attitudes2 = list()

for tweet in df['tweet']:
    testimonial = TextBlob(str(tweet))
    attitude1 = testimonial.sentiment.polarity
    attitudes1.append(attitude1)
df['textblob'] = attitudes1

sid = SentimentIntensityAnalyzer()
for tweet in df['tweet']:
    attitude2 = sid.polarity_scores(tweet)['compound']
    attitudes2.append(attitude2)
df['nltk_vader'] = attitudes2

print(df.head())
print(df.tail())

df.to_csv('attitudes_impossible_whopper.csv',mode='w')
# Out:
# False    1945
# Name: tweet, dtype: int64
#         date         username  \
# 0  2019/8/31      shar_parker
# 1  2019/8/31  clemsonhandyman
# 2  2019/8/31     glorianne329
# 3  2019/8/31  drachonathewolf
# 4  2019/8/31        sssaaadie
#
#                                                tweet  textblob  nltk_vader
# 0                @ImpossibleFoods #impossiblewhopper  0.000000      0.0000
# 1  #impossiblewhopper had 2nd one an it鈥檚 good ag...  0.350000      0.4404
# 2  Ok @BurgerKing 馃憦 馃憦 馃憦 my vegetarian husband ...  0.566667      0.9449
# 3  Hey @BurgerKing , I'm not stupid. The #impossi...  0.100000      0.4168
# 4                                 #impossiblewhopper  0.000000      0.0000
#            date      username  \
# 1940  2019/5/10  rachelkonrad
# 1941  2019/5/10  justinthaler
# 1942   2019/5/9    nickkeesey
# 1943   2019/5/8  rachelkonrad
# 1944   2019/5/6   tiffanireal
#
#                                                   tweet  textblob  nltk_vader
# 1940  Truth: @BurgerKing sells the #impossiblewhoppe... -0.138889      0.5994
# 1941  As long as that joke involves the #impossiblew...  0.412500      0.6588
# 1942  @BurgerKing when will the @ImpossibleFoods who...  0.000000      0.1007
# 1943  Fact: #impossibleWhopper is in 59 stores. That... -0.055556     -0.1280
# 1944         I can't wait to try the #impossiblewhopper  0.000000      0.0000

# %%
df2=pd.read_csv('C:/Users/norton/Google 云端硬盘（qliu101@fordham.edu）/1. Fall 2019/2. Web Analytics/Project/FINAL/attitudes_impossible_whopper.csv',
               delimiter=',',
               encoding='utf-8',
               header=0,
               names=['date', 'username','tweet','textblob','nltk_vader'])

# %%
df2.describe()
# Out:
#           textblob   nltk_vader
# count  1945.000000  1945.000000
# mean      0.150319     0.282913
# std       0.346946     0.460904
# min      -1.000000    -0.953100
# 25%       0.000000     0.000000
# 50%       0.105903     0.361200
# 75%       0.350000     0.680800
# max       1.000000     0.985800
